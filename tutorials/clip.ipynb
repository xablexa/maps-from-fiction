# %% [markdown]
# # CLIP Classification

# %% [markdown]
# For the secondary classification, we used CLIP with a prompt to classify the remaining images. Although CLIP can be finetuned, we did not do that here. Instead, we took a set of images that
